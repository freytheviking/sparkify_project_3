# %% [markdown]
# # Test Sparkify's S3 to Redshift ETL Notebook
#
# This notebook is used as a sanity check to see if the ETL process worked properly. We will connect to the Redshift cluster and use several queries to make sure everything worked properly.

# %% [markdown]
# ### Import Libraries

# %%
from configparser import ConfigParser
import psycopg2
import psycopg2.extras
import pandas as pd

from utils import *

# %% [markdown]
# ### Connect to Database

# %%
# Get information from configuration and
# connect to Redshift
config = ConfigParser()
config.read_file(open('dwh.cfg'))

conn_string = "host={} dbname={} user={} password={} port={}".format(*config['CLUSTER'].values())
conn = psycopg2.connect(conn_string)

print(conn_string)
# Out:
# host=redshiftdwh.c0fxig4ucntn.us-west-2.redshift.amazonaws.com dbname=dev user=awsuser password=Redshift0 port=5439

# %% [markdown]
# ### Test SQL Queries

# %%
# https://stackoverflow.com/questions/35604186/convert-psycopg2-dictrow-query-to-pandas-dataframe
# This returns the headers of each tuple/row so we can get the column names
cur = conn.cursor(cursor_factory=psycopg2.extras.DictCursor)

# %%
query = """
    SELECT page, count(*)
    FROM staging_events
    GROUP BY page
"""

execute_query(cur=cur, query=query)
# Out:
#                 page  count
# 0              Login     92
# 1               Home    806
# 2           NextSong   6820
# 3          Downgrade     60
# 4           Settings     56
# 5      Save Settings     10
# 6             Logout     90
# 7               Help     47
# 8              Error      9
# 9            Upgrade     21
# 10    Submit Upgrade      8
# 11             About     36
# 12  Submit Downgrade      1

# %%
query = """
    SELECT * FROM staging_songs LIMIT 5;
"""

execute_query(cur=cur, query=query)
# Out:
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARCLYBR1187FB53913         37.54703        -122.31483
# 1          1  ARCZBX11187B9AD089              NaN               NaN
# 2          1  AR9E1QW1187B999A34              NaN               NaN
# 3          1  ARZJDBC1187FB52056         27.94017         -82.32547
# 4          1  ARPQ4Z01187FB3A736         29.42449         -98.49462
#
#     artist_location       artist_name             song_id  \
# 0     San Mateo, CA        Neal Schon  SOOVHYF12A8C134892
# 1                    Suicide Commando  SOVROYO12AB0186D09
# 2                      Mikel Erentxun  SOSBVKG12A8C1409B8
# 3  Brandon, Florida      Nasty Savage  SORUZFR12AB01866C1
# 4   San Antonio, TX  Butthole Surfers  SOJXVAH12A8C139700
#
#                            title   duration  year
# 0                I'll Be Waiting  304.56118  1989
# 1                  Blood In Face  287.29424  2000
# 2                   En Que Mujer  210.33751  2000
# 3                Hypnotic Trance  280.37179  1987
# 4  Barking Dogs (From "Piouhgd")  450.84689     0

# %%
query = """
    SELECT * FROM songplays LIMIT 5
"""

execute_query(cur=cur, query=query)
# Out:
#    songplay_id      timestamp             song_id           artist_id user_id  \
# 0           18  1541106673796  SOEIQUY12AF72A086A  ARHUC691187B9AD27F       8
# 1          184  1541179905796  SOHTKMO12AB01843B0  AR5EYTL1187B98EDA0      10
# 2          171  1541267941796  SOHTKMO12AB01843B0  AR5EYTL1187B98EDA0      15
# 3          353  1541273619796  SOYTFSY12A6D4FD84E  ARRFSMX1187FB39B03      95
# 4           90  1541348754796  SOARUPP12AB01842E0  ARD46C811C8A414F3F      69
#
#    session_id level                                      location  \
# 0         139  free                   Phoenix-Mesa-Scottsdale, AZ
# 1         182  free  Washington-Arlington-Alexandria, DC-VA-MD-WV
# 2         199  paid            Chicago-Naperville-Elgin, IL-IN-WI
# 3         152  paid                             Winston-Salem, NC
# 4         235  free   Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
#
#                                           user_agent
# 0  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 1  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 2  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 3  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# 4  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...

# %%
# List artists with the most number plays descending
query = """
SELECT
    a.artist_name,
    a.artist_id,
    count(*) AS count
FROM songplays sp
JOIN artists a 
ON sp.artist_id = a.artist_id
GROUP BY a.artist_id, a.artist_name
ORDER BY count DESC
LIMIT 5
"""

execute_query(cur=cur, query=query)
# Out:
#                       artist_name           artist_id  count
# 0                   Dwight Yoakam  AR5E44Z1187B9A1D74     37
# 1  Kid Cudi / Kanye West / Common  ARD46C811C8A414F3F     10
# 2                      Ron Carter  AR37SX11187FB3E164      9
# 3                   Lonnie Gordon  AR5EYTL1187B98EDA0      9
# 4                           B.o.B  ARKQQZA12086C116FC      8

# %%
# List users by average session duration descending
query = """
SELECT
    avg(sessions.duration) AS mean_duration,
    user_id
FROM (
    SELECT
        max(timestamp) - min(timestamp) AS duration,
        session_id,
        user_id
    FROM songplays
    GROUP BY session_id, user_id
) sessions
GROUP BY user_id
ORDER BY mean_duration DESC
LIMIT 5
"""

execute_query(cur=cur, query=query)
# Out:
#    mean_duration user_id
# 0        9810000      30
# 1        8204400      24
# 2        5919000      72
# 3        5491454      97
# 4        5082000      15

# %% [markdown]
# ### Drop All Tables and Disconnect from Redshift

# %%
drop_tables(cur, conn)
delete_staging_tables(cur, conn)

# %%
conn.close()
